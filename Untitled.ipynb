# %%
import pandas as pd
import streamlit as st
import os

pd.read_csv("users.csv")

pd.read_csv("progress.csv")
# Out:
#    username;dag;cardio;kracht
# 0                Gideon;1;1;0
# 1                Gideon;2;0;0
# 2                Gideon;3;0;0
# 3                Gideon;4;0;0
# 4                Gideon;5;0;0
# 5                Gideon;6;0;0
# 6                Gideon;7;0;0
# 7                Gideon;8;0;0
# 8                Gideon;9;0;0
# 9               Gideon;10;0;0
# 10              Gideon;11;0;0
# 11              Gideon;12;0;0
# 12                 test;1;0;0
# 13                 test;2;0;0
# 14                 test;3;0;0
# 15                 test;4;0;0
# 16                 test;5;0;0
# 17                 test;6;0;0
# 18                 test;7;0;0
# 19                 test;8;0;0
# 20                 test;9;0;0
# 21                test;10;0;0
# 22                test;11;0;0
# 23                test;12;0;0
